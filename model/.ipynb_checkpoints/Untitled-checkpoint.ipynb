# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
import nltk
warnings.filterwarnings(action='ignore')

# %%
df_game=pd.read_csv("../data/all_game.csv")
df_game_s=df_game[['title','userscore','summary']]
df_game_s
# Out:
#                                                 title  userscore  \
# 0               Surgeon Simulator: Experience Reality       4.40
# 1                Transformers: Rise of the Dark Spark       4.20
# 2                                         NBA Live 14       2.60
# 3                                            WWE 2K20       1.60
# 4                                            VR Karts       5.60
# ...                                               ...        ...
# 14350                                         Road 96       6.70
# 14351              WRC 9 FIA World Rally Championship       6.00
# 14352                                Shadow Warrior 3       6.00
# 14353  Blast Brigade vs. the Evil Legion of Dr. Cread       6.53
# 14354             Taiko no Tatsujin: The Drum Master!       8.00
#
#                                                  summary
# 0      This game is ridiculously fun once you ve plac...
# 1      Fight your way through both Earth and Cybertro...
# ...

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords=nltk.corpus.stopwords.words('english')
df_game['token_summary'] = df_game['summary'].apply(nltk.word_tokenize)
df_game['tokenized'] = train_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
df_game
# Out:
#                                                 title  metascore  userscore  \
# 0               Surgeon Simulator: Experience Reality         43       4.40
# 1                Transformers: Rise of the Dark Spark         43       4.20
# 2                                         NBA Live 14         43       2.60
# 3                                            WWE 2K20         43       1.60
# 4                                            VR Karts         42       5.60
# ...                                               ...        ...        ...
# 14350                                         Road 96         78       6.70
# 14351              WRC 9 FIA World Rally Championship         78       6.00
# 14352                                Shadow Warrior 3         78       6.00
# 14353  Blast Brigade vs. the Evil Legion of Dr. Cread         78       6.53
# 14354             Taiko no Tatsujin: The Drum Master!         78       8.00
#
# ...

# %% [markdown]
# 전처리

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplcursors # Use this is for creating a cursor-interactive plot with "%matplotlib notebook"
from sklearn.decomposition import NMF # Use this for training Non-negative Matrix Factorization
from sklearn.utils.extmath import randomized_svd # Use this for training Singular Value Decomposition
from sklearn.manifold import TSNE # Use this for training t-sne manifolding

plt.style.use('ggplot') # You can also use different style

# just for plot checking, use this option
# %matplotlib inline

# for interactive plot
# If you use this option, plot will appear at first-drawn position
# %matplotlib notebook

warnings.filterwarnings('ignore')

# %% [markdown]
# 데이터셋 불러오기
# 데이터셋 출처 https://www.kaggle.com/datasets/deepcontractor/top-video-games-19952021-metacritic
# 데이터셋 1995년부터 2021년까지의 자료
# all_games.csv의 칼럼
# names platform release_date summary(게임 요약) meta_score(전문가 스코어 100점만점) user_review(유저스코어 10점만점)

# %%
dir = './dataset/'
df_games=pd.read_csv(dir+'all_games.csv',usecols=['name','platform','release_date','meta_score','user_review'])

# %% [markdown]
# 게임수 파악
# 6546개의 플랫폼이 다른 동일 게임이 존재

# %%
n_games=len(df_games['name'])
n_game_same_name=len(df_games['name'].unique())
n_games,n_game_same_name,n_games-n_game_same_name
# Out:
# (18800, 12254, 6546)

# %% [markdown]
# 이름이없는 row 존재하지않음

# %%
len(df_games)-n_games
# Out:
# 0

# %% [markdown]
# 칼럼 타입 확인하기

# %%
df_games.dtypes
# Out:
# name            object
# platform        object
# release_date    object
# meta_score       int64
# user_review     object
# dtype: object

# %% [markdown]
# user_review칼럼에서 tbd(미정)값 존재 확인

# %%
df_games.astype({'name':'string','platform':'string','release_date':'string','user_review':'string'})
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score user_review
# 0       November 23, 1998          99         9.1
# 1      September 20, 2000          98         7.4
# 2          April 29, 2008          98         7.7
# 3       September 8, 1999          98         8.4
# 4          April 29, 2008          98         7.9
# ...                   ...         ...         ...
# 18795        May 21, 2013          22         1.3
# 18796    November 3, 2003          22         1.7
# 18797  September 22, 2015          21         2.9
# 18798    October 15, 2012          20         1.7
# 18799      March 31, 2009          20         2.0
#
# [18800 rows x 5 columns]

# %% [markdown]
# user review칼럼에서 tbd값이 포함된 row처리?
#
# 일단 0.0점으로 변경(알고리즘에 따라 달라질듯)

# %%
df_games.loc[df_games.user_review=='tbd','user_review']='0.0'

# %% [markdown]
# tbd값 처리후 데이터타입 float으로 변경

# %%
df_games.astype({'user_review':'float'})
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score  user_review
# 0       November 23, 1998          99          9.1
# 1      September 20, 2000          98          7.4
# 2          April 29, 2008          98          7.7
# 3       September 8, 1999          98          8.4
# 4          April 29, 2008          98          7.9
# ...                   ...         ...          ...
# 18795        May 21, 2013          22          1.3
# 18796    November 3, 2003          22          1.7
# 18797  September 22, 2015          21          2.9
# 18798    October 15, 2012          20          1.7
# 18799      March 31, 2009          20          2.0
#
# [18800 rows x 5 columns]

# %% [markdown]
# 칼럼추가

# %% [markdown]
# 데이터프레임 csv로 변환

# %%
df_games.to_csv(dir+'all_games_proc.csv',sep=',',float_format='%.2f',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20772\1402362008.py in <module>
# ----> 1 df_games.to_csv(dir+'all_games_proc.csv',sep=',',float_format='%.2f',index=False)
#
# NameError: name 'df_games' is not defined

# %%
dir2="../crawling/"
df_games2=pd.read_csv(dir2+'ps4.csv')
df_games2
# Out:
#      userscore                                              title  \
# 0          7.8                                         Spelunky 2
# 1          6.8                                          Fallout 4
# 2          8.6             Uncharted: The Nathan Drake Collection
# 3          8.2  Tales from the Borderlands: A Telltale Game Se...
# 4          7.5                                            F1 2017
# ..         ...                                                ...
# 195        8.2                            Odin Sphere Leifthrasir
# 196        7.7            Dark Souls II: Scholar of the First Sin
# 197        7.8                                   Sonic Mania Plus
# 198        5.2                                      Psychonauts 2
# 199        6.7                                           NBA 2K16
#
#                                                 genres  \
# 0                                Action|Platformer|2D|
# 1                  General|Role-Playing|Western-Style|
# 2    Miscellaneous|Action Adventure|General|Compila...
# 3                                   Adventure|General|
# 4                        Racing|Simulation|Automobile|
# ..                                                 ...
# 195                           Role-Playing|Action RPG|
# 196                           Role-Playing|Action RPG|
# 197                              Action|Platformer|2D|
# 198  Action|Platformer|3D|Beat-'Em-Up|Action Advent...
# 199         Action|General|Sports|Team|Basketball|Sim|
#
#                    developer  metascore  \
# 0                  Mossmouth         87
# 1      Bethesda Game Studios         87
# 2            Bluepoint Games         86
# 3             Telltale Games         86
# 4                Codemasters         86
# ..                       ...        ...
# 195              Vanillaware         87
# 196            From Software         87
# 197                     Sega         87
# 198  Double Fine Productions         87
# 199          Visual Concepts         87
#
#                                                summary             publisher  \
# 0    Cenários e gameplay repleto de segredos, físic...             Mossmouth
# 1    Even decades after Bethesda started making gam...    Bethesda Softworks
# 2    From the storytellers at Naughty Dog, comes th...                  SCEA
# 3    Like all good tales, there’s more than one sid...  Take-Two Interactive
# 4    Win the 2017 World Championship, break every r...           Codemasters
# ..                                                 ...                   ...
# 195  The tale of Armageddon is about to be told... ...                 Atlus
# 196  Dark Souls II: Scholar of the First Sin includ...    Bandai Namco Games
# 197  With the addition of encore mode, this game is...                  Sega
# 198  Razputin Aquato, trained acrobat and powerful ...            Starbreeze
# 199  Be the Story. The NBA 2K franchise is back wit...  Take-Two Interactive
#
#      release_date rating
# 0    Sep 15, 2020      T
# 1    Nov 10, 2015      M
# 2    Oct  9, 2015      T
# 3    Oct 20, 2015      M
# 4    Aug 25, 2017      E
# ..            ...    ...
# 195  Jun  7, 2016      T
# 196  Apr  7, 2015      T
# 197  Jul 17, 2018      E
# 198  Aug 25, 2021      T
# 199  Sep 25, 2015   E10+
#
# [200 rows x 9 columns]
